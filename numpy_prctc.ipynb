# %% [markdown]
# <a href="https://colab.research.google.com/github/Nilofar87/Nilo_Repo/blob/main/numpy_prctc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+1
# Out:
# 3

# %%
import numpy as np

# %%
one = np.array([1,2,3,4,5])

# %%
np.ndim(one)
# Out:
# 1

# %%
two = np.array([[1,2,3],[7,8,9]])

# %%
two
# Out:
# array([[1, 2, 3],
#        [7, 8, 9]])

# %%
np.ndim(two)
# Out:
# 2

# %%
three = np.array([[[10,20,30,40],[50,60,70,80]],[[11,22,33,44],[55,66,77,88]]])

# %%
three
# Out:
# array([[[10, 20, 30, 40],
#         [50, 60, 70, 80]],
#
#        [[11, 22, 33, 44],
#         [55, 66, 77, 88]]])

# %%
np.ndim(three)
# Out:
# 3

# %%
arr = np.array([11,22,3.5,'apple','banana'])

# %%
arr
# Out:
# array(['11', '22', '3.5', 'apple', 'banana'], dtype='<U32')

# %%
np.ndim(arr)
# Out:
# 1

# %%
# array allows methematical operations

a=np.array([2,5,7,9,10])

a/2
# Out:
# array([1. , 2.5, 3.5, 4.5, 5. ])

# %%
print(a/5)
# Out:
# [0.4 1.  1.4 1.8 2. ]
